# %%
import os
import pandas as pd
from IPython.display import display

# %%
INPUT_PATH = '../input/'

# %%
df_files = []
for f in os.listdir(INPUT_PATH):
    df_files.append(f)

df_files
# Out:
# ['train.csv',
#  'alldata_transform.csv',
#  'df_pipe11.csv',
#  'df_pipe9.csv',
#  'test.csv',
#  'pred_Lasso.csv',
#  'pred_SVR.csv',
#  'df_pipe5.csv',
#  'df_pipe2.csv',
#  'df_pipe4.csv',
#  'pred_AdaBoostRegressor.csv',
#  'df_pipe3.csv',
#  'df_pipe10.csv',
#  'df_pipe8.csv',
#  'pred_LinearRegression.csv',
#  'pred_ExtraTreesRegressor.csv',
#  'train_folds.csv',
#  'df_pipe6.csv',
#  'df_gridsearch_pipe8.csv',
#  'pred_Ridge.csv',
#  'df_randomsearch_pipe8.csv',
#  'df_pipe7.csv',
#  'leaderboard.csv',
#  'raw.csv',
#  'pred_RandomForestRegressor.csv',
#  'pred_GradientBoostingRegressor.csv',
#  'mpg_clean.csv',
#  'df_pipe1.csv']

# %%
for f in df_files:
    display(pd.read_csv(INPUT_PATH + f).head())
    print("{}".format(f))
# Out:
#    target  cylinders  displacement  horsepower  weight  acceleration  \
# 0    27.5          4         134.0        95.0    2560          14.2
# 1    18.0          6         199.0        97.0    2774          15.5
# 2    11.0          8         429.0       208.0    4633          11.0
# 3    17.0          6         231.0       110.0    3907          21.0
# 4    14.0          8         440.0       215.0    4312           8.5
#
#    model_year origin               name
# 0          78  japan      toyota corona
# 1          70    usa         amc hornet
# 2          72    usa    mercury marquis
# 3          75    usa      buick century
# 4          70    usa  plymouth fury iii
# train.csv
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          2         307.0       130.0    3504          12.0           0
# 1          2         350.0       165.0    3693          11.5           0
# 2          2         318.0       150.0    3436          11.0           0
# ...
